# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\uday\appdata\local\programs\python\python312\lib\site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\uday\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (5.0.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\uday\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\uday\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\uday\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uday\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uday\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uday\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#authentication for extraction of data from spontify
client_credentials_manager = SpotifyClientCredentials(client_id="", client_secret="")

# %%
#spontify object
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link="https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_uri = playlist_link.split('/')[-1]

# %%
data=sp.playlist_tracks(playlist_uri)
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-10-27T08:45:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jbo7KFNMiIkfBR6ih0yhm'},
#        'href': 'https://api.spotify.com/v1/artists/0jbo7KFNMiIkfBR6ih0yhm',
#        'id': '0jbo7KFNMiIkfBR6ih0yhm',
#        'name': 'iñigo quintero',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jbo7KFNMiIkfBR6ih0yhm'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/66k6EGkPtYoN44anGIsEPW'},
#      'href': 'https://api.spotify.com/v1/albums/66k6EGkPtYoN44anGIsEPW',
#      'id': '66k6EGkPtYoN44anGIsEPW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735cb9531348f45311cd6fb8df',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025cb9531348f45311cd6fb8df',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515cb9531348f45311cd6fb8df',
#        'width': 64}],
#      'name': 'Si No Estás',
#      'release_date': '2022-09-23',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:66k6EGkPtYoN44anGIsEPW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jbo7KFNMiIkfBR6ih0yhm'},
#       'href': 'https://api.spotify.com/v1/artists/0jbo7KFNMiIkfBR6ih0yhm',
#       'id': '0jbo7KFNMiIkfBR6ih0yhm',
#       'name': 'iñigo quintero',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jbo7KFNMiIkfBR6ih0yhm'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 184061,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAGM2208561'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2HafqoJbgXdtjwCOvNEF14'},
#     'href': 'https://api.spotify.com/v1/tracks/2HafqoJbgXdtjwCOvNEF14',
#     'id': '2HafqoJbgXdtjwCOvNEF14',
#     'is_local': False,
#     'name': 'Si No Estás',
#     'popularity': 98,
#     'preview_url': 'https://p.scdn.co/mp3-preview/28d6d99074f2f2d7e70597d3213099ca04e75116?cid=7bc584d74534470091c4d94b3298bb5c',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2HafqoJbgXdtjwCOvNEF14'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-10-27T08:45:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#        'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym',
#        'id': '45dkTj5sMRSjrmBSBeiHym',
#        'name': 'Tate McRae',
#        'type': 'artist',
#        'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#      'href': 'https://api.spotify.com/v1/albums/3UOV8XvCwMKaATRNXrYCjN',
#      'id': '3UOV8XvCwMKaATRNXrYCjN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27322fd802bc61db666c7c81aa8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0222fd802bc61db666c7c81aa8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485122fd802bc61db666c7c81aa8',
#        'width': 64}],
#      'name': 'greedy',
#      'release_date': '2023-09-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3UOV8XvCwMKaATRNXrYCjN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#       'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym',
#       'id': '45dkTj5sMRSjrmBSBeiHym',
#       'name': 'Tate McRae',
#       'type': 'artist',
#       'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 131872,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC12301932'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3rUGC1vUpkDG9CZFHMur1t'},
#     'href': 'https://api.spotify.com/v1/tracks/3rUGC1vUpkDG9CZFHMur1t',
#     'id': '3rUGC1vUpkDG9CZFHMur1t',
#     'is_local': False,
#     'name': 'greedy',
#     'popularity': 99,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ca7bdcb691fb64a5af8a3253b89356390664fcf1?cid=7bc584d74534470091c4d94b3298bb5c',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3rUGC1vUpkDG9CZFHMur1t'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-10-27T08:45:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#        'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#        'id': '6HaGTQPmzraVmaVxvz6EUc',
#        'name': 'Jung Kook',
#        'type': 'artist',
#        'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#        'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#        'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#        'name': 'Latto',
#        'type': 'artist',
#        'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'},
#      'href': 'https://api.spotify.com/v1/albums/53985D8g3JcGBoULSOYYKX',
#      'id': '53985D8g3JcGBoULSOYYKX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf5cce5a0e1ed03a626bdd74',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf5cce5a0e1ed03a626bdd74',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf5cce5a0e1ed03a626bdd74',
#        'width': 64}],
#      'name': 'Seven (feat. Latto)',
#      'release_date': '2023-07-14',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:53985D8g3JcGBoULSOYYKX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#       'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#       'id': '6HaGTQPmzraVmaVxvz6EUc',
#       'name': 'Jung Kook',
#       'type': 'artist',
#       'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#       'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#       'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#       'name': 'Latto',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 184400,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USA2P2330093'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7x9aauaA9cu6tyfpHnqDLo'},
#     'href': 'https://api.spotify.com/v1/tracks/7x9aauaA9cu6tyfpHnqDLo',
#     'id': '7x9aauaA9cu6tyfpHnqDLo',
#     'is_local': False,
#     'name': 'Seven (feat. Latto) (Explicit Ver.)',
#     'popularity': 97,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2f2b3f4eaf405ac3ba9792456cec93ae88942cfc?cid=7bc584d74534470091c4d94b3298bb5c',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7x9aauaA9cu6tyfpHnqDLo'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-10-27T08:45:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#        'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#        'id': '4q3ewBCX7sLwd24euuV69X',
#        'name': 'Bad Bunny',
#        'type': 'artist',
#        'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4FftCsAcXXD1nFO9RFUNFO'},
#      'href': 'https://api.spotify.com/v1/albums/4FftCsAcXXD1nFO9RFUNFO',
#      'id': '4FftCsAcXXD1nFO9RFUNFO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737b1fc51ff3257b5286a1ecec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027b1fc51ff3257b5286a1ecec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517b1fc51ff3257b5286a1ecec',
#        'width': 64}],
#      'name': 'nadie sabe lo que va a pasar mañana',
#      'release_date': '2023-10-13',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:4FftCsAcXXD1nFO9RFUNFO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 267194,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'QMFME2364182'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4MjDJD8cW7iVeWInc2Bdyj'},
#     'href': 'https://api.spotify.com/v1/tracks/4MjDJD8cW7iVeWInc2Bdyj',
#     'id': '4MjDJD8cW7iVeWInc2Bdyj',
#     'is_local': False,
#     'name': 'MONACO',
#     'popularity': 97,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f80c7cc394457fc77cd6668a715b039fd86404f9?cid=7bc584d74534470091c4d94b3298bb5c',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4MjDJD8cW7iVeWInc2Bdyj'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-10-27T08:45:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#        'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#        'id': '4q3ewBCX7sLwd24euuV69X',
#        'name': 'Bad Bunny',
#        'type': 'artist',
#        'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4FftCsAcXXD1nFO9RFUNFO'},
#      'href': 'https://api.spotify.com/v1/albums/4FftCsAcXXD1nFO9RFUNFO',
#      'id': '4FftCsAcXXD1nFO9RFUNFO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737b1fc51ff3257b5286a1ecec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027b1fc51ff3257b5286a1ecec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517b1fc51ff3257b5286a1ecec',
#        'width': 64}],
#      'name': 'nadie sabe lo que va a pasar mañana',
#      'release_date': '2023-10-13',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:4FftCsAcXXD1nFO9RFUNFO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2LRoIwlKmHjgvigdNGBHNo'},
#       'href': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo',
#       'id': '2LRoIwlKmHjgvigdNGBHNo',
#       'name': 'Feid',
#       'type': 'artist',
#       'uri': 'spotify:artist:2LRoIwlKmHjgvigdNGBHNo'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 162767,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'QMFME2364199'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7iQXYTyuG13aoeHxGG28Nh'},
#     'href': 'https://api.spotify.com/v1/tracks/7iQXYTyuG13aoeHxGG28Nh',
#     'id': '7iQXYTyuG13aoeHxGG28Nh',
#     'is_local': False,
#     'name': 'PERRO NEGRO',
#     'popularity': 96,
#     'preview_url': 'https://p.scdn.co/mp3-preview/56ebd640e918ff135fed691da3c5697568e60a77?cid=7bc584d74534470091c4d94b3298bb5c',
#     'track': True,
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:7iQXYTyuG13aoeHxGG28Nh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-10-27T08:45:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#        'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#        'id': '5cj0lLjcoR7YOSnhnX0Po5',
#        'name': 'Doja Cat',
#        'type': 'artist',
#        'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1bBez9PNvkJPW08bU7NYta'},
#      'href': 'https://api.spotify.com/v1/albums/1bBez9PNvkJPW08bU7NYta',
#      'id': '1bBez9PNvkJPW08bU7NYta',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a840032f14ab22da396e43cb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a840032f14ab22da396e43cb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a840032f14ab22da396e43cb',
#        'width': 64}],
#      'name': 'Scarlet',
#      'release_date': '2023-09-20',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1bBez9PNvkJPW08bU7NYta'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#       'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#       'id': '5cj0lLjcoR7YOSnhnX0Po5',
#       'name': 'Doja Cat',
#       'type': 'artist',
#       'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 230480,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC12300907'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/56y1jOTK0XSvJzVv9vHQBK'},
#     'href': 'https://api.spotify.com/v1/tracks/56y1jOTK0XSvJzVv9vHQBK',
#     'id': '56y1jOTK0XSvJzVv9vHQBK',
#     'is_local': False,
#     'name': 'Paint The Town Red',
#     'popularity': 89,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f544992f165d4bd069f4d903ff946dc625ba0b8e?cid=7bc584d74534470091c4d94b3298bb5c',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:56y1jOTK0XSvJzVv9vHQBK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-10-27T08:45:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#      'href': 'https://api.spotify.com/v1/albums/1NAmidJlEaVgA3MpcPFYGq',
#      'id': '1NAmidJlEaVgA3MpcPFYGq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e787cffec20aa2a396a61647',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e787cffec20aa2a396a61647',
#        'width': 64}],
#      'name': 'Lover',
#      'release_date': '2019-08-23',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:1NAmidJlEaVgA3MpcPFYGq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 178426,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11901472'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr'},
#     'href': 'https://api.spotify.com/v1/tracks/1BxfuPKGuaTgP7aM0Bbdwr',
#     'id': '1BxfuPKGuaTgP7aM0Bbdwr',
#     'is_local': False,
# ...
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 200600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12209777'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7DSAEUvxU8FajXtRloy8M0'},
#     'href': 'https://api.spotify.com/v1/tracks/7DSAEUvxU8FajXtRloy8M0',
#     'id': '7DSAEUvxU8FajXtRloy8M0',
#     'is_local': False,
#     'name': 'Flowers',
#     'popularity': 92,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5184d19d1b7fcc3e7c067e38af45a7cc80851440?cid=7bc584d74534470091c4d94b3298bb5c',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7DSAEUvxU8FajXtRloy8M0'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-10-27T08:45:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr'},
#      'href': 'https://api.spotify.com/v1/albums/2fenSS68JI1h4Fo296JfGr',
#      'id': '2fenSS68JI1h4Fo296JfGr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc',
#        'width': 64}],
#      'name': 'folklore',
#      'release_date': '2020-07-24',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:2fenSS68JI1h4Fo296JfGr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 261922,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG12002842'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3hUxzQpSfdDqwM3ZTFQY0K'},
#     'href': 'https://api.spotify.com/v1/tracks/3hUxzQpSfdDqwM3ZTFQY0K',
#     'id': '3hUxzQpSfdDqwM3ZTFQY0K',
#     'is_local': False,
#     'name': 'august',
#     'popularity': 92,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:3hUxzQpSfdDqwM3ZTFQY0K'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-10-27T08:45:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#        'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#        'id': '7tYKF4w9nC0nq9CsPZTHyP',
#        'name': 'SZA',
#        'type': 'artist',
#        'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/07w0rG5TETcyihsEIZR3qG'},
#      'href': 'https://api.spotify.com/v1/albums/07w0rG5TETcyihsEIZR3qG',
#      'id': '07w0rG5TETcyihsEIZR3qG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27370dbc9f47669d120ad874ec1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0270dbc9f47669d120ad874ec1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485170dbc9f47669d120ad874ec1',
#        'width': 64}],
#      'name': 'SOS',
#      'release_date': '2022-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:07w0rG5TETcyihsEIZR3qG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#       'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#       'id': '7tYKF4w9nC0nq9CsPZTHyP',
#       'name': 'SZA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 201800,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC12204591'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4iZ4pt7kvcaH6Yo8UoZ4s2'},
#     'href': 'https://api.spotify.com/v1/tracks/4iZ4pt7kvcaH6Yo8UoZ4s2',
#     'id': '4iZ4pt7kvcaH6Yo8UoZ4s2',
#     'is_local': False,
#     'name': 'Snooze',
#     'popularity': 92,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8c53920b5fd2c3178afa36cac9eec68b5ee9204a?cid=7bc584d74534470091c4d94b3298bb5c',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 50}

# %%
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jbo7KFNMiIkfBR6ih0yhm'},
#     'href': 'https://api.spotify.com/v1/artists/0jbo7KFNMiIkfBR6ih0yhm',
#     'id': '0jbo7KFNMiIkfBR6ih0yhm',
#     'name': 'iñigo quintero',
#     'type': 'artist',
#     'uri': 'spotify:artist:0jbo7KFNMiIkfBR6ih0yhm'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/66k6EGkPtYoN44anGIsEPW'},
#   'href': 'https://api.spotify.com/v1/albums/66k6EGkPtYoN44anGIsEPW',
#   'id': '66k6EGkPtYoN44anGIsEPW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735cb9531348f45311cd6fb8df',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025cb9531348f45311cd6fb8df',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515cb9531348f45311cd6fb8df',
#     'width': 64}],
#   'name': 'Si No Estás',
#   'release_date': '2022-09-23',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:66k6EGkPtYoN44anGIsEPW'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jbo7KFNMiIkfBR6ih0yhm'},
#    'href': 'https://api.spotify.com/v1/artists/0jbo7KFNMiIkfBR6ih0yhm',
#    'id': '0jbo7KFNMiIkfBR6ih0yhm',
#    'name': 'iñigo quintero',
#    'type': 'artist',
#    'uri': 'spotify:artist:0jbo7KFNMiIkfBR6ih0yhm'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 184061,
#  'episode': False,
#  'explicit': False,
#  'external_ids': {'isrc': 'TCAGM2208561'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2HafqoJbgXdtjwCOvNEF14'},
#  'href': 'https://api.spotify.com/v1/tracks/2HafqoJbgXdtjwCOvNEF14',
#  'id': '2HafqoJbgXdtjwCOvNEF14',
#  'is_local': False,
#  'name': 'Si No Estás',
#  'popularity': 98,
#  'preview_url': 'https://p.scdn.co/mp3-preview/28d6d99074f2f2d7e70597d3213099ca04e75116?cid=7bc584d74534470091c4d94b3298bb5c',
#  'track': True,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:2HafqoJbgXdtjwCOvNEF14'}

# %%
data['items'][0]['track']['album']['id']
# Out:
# '66k6EGkPtYoN44anGIsEPW'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Si No Estás'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2022-09-23'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/66k6EGkPtYoN44anGIsEPW'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_data = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id, 'album_name':album_name, 'album_release_data':album_release_data, 'album_total_tracks':album_total_tracks,
                    'album_url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '1bBez9PNvkJPW08bU7NYta',
#   'album_name': 'Scarlet',
#   'album_release_data': '2023-09-20',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/1bBez9PNvkJPW08bU7NYta'},
#  {'album_id': '53985D8g3JcGBoULSOYYKX',
#   'album_name': 'Seven (feat. Latto)',
#   'album_release_data': '2023-07-14',
#   'album_total_tracks': 3,
#   'album_url': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'album_name': 'Lover',
#   'album_release_data': '2019-08-23',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '18ogtNq9F7DmMkNYO6Xb4k',
#   'album_name': 'Strangers',
#   'album_release_data': '2023-09-01',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/18ogtNq9F7DmMkNYO6Xb4k'},
#  {'album_id': '0FqAaUEyKCyUNFE1uQPZ7i',
#   'album_name': 'MAÑANA SERÁ BONITO (BICHOTA SEASON)',
#   'album_release_data': '2023-08-10',
#   'album_total_tracks': 9,
#   'album_url': 'https://open.spotify.com/album/0FqAaUEyKCyUNFE1uQPZ7i'},
#  {'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'album_name': 'greedy',
#   'album_release_data': '2023-09-15',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#  {'album_id': '3puAvurwvtvi1rodndIPW8',
#   'album_name': 'LA VIDA ES UNA',
#   'album_release_data': '2023-03-23',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/3puAvurwvtvi1rodndIPW8'},
#  {'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'album_name': 'GUTS',
#   'album_release_data': '2023-09-08',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'},
#  {'album_id': '07kam1Dks7GIucbSelfvyX',
#   'album_name': 'Columbia',
#   'album_release_data': '2023-07-07',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/07kam1Dks7GIucbSelfvyX'},
#  {'album_id': '4jox3ip1I39DFC2B7R5qLH',
#   'album_name': 'GÉNESIS',
#   'album_release_data': '2023-06-29',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/4jox3ip1I39DFC2B7R5qLH'},
#  {'album_id': '3AafSrFIbJPH6BJHiJm1Cd',
#   'album_name': 'What Was I Made For? [From The Motion Picture "Barbie"]',
#   'album_release_data': '2023-07-13',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3AafSrFIbJPH6BJHiJm1Cd'},
#  {'album_id': '5cH7FqB7JD5q1tJXJ7FHYu',
#   'album_name': 'Dance The Night (From Barbie The Album)',
#   'album_release_data': '2023-05-25',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5cH7FqB7JD5q1tJXJ7FHYu'},
#  {'album_id': '5qmZefgh78fN3jsyPPlvuw',
#   'album_name': 'a Gift & a Curse',
#   'album_release_data': '2023-06-16',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/5qmZefgh78fN3jsyPPlvuw'},
#  {'album_id': '6NcI39WPu4kY6Tul11nhSv',
#   'album_name': 'Daylight',
#   'album_release_data': '2023-04-14',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/6NcI39WPu4kY6Tul11nhSv'},
#  {'album_id': '78bpIziExqiI9qztvNFlQu',
#   'album_name': 'AM',
#   'album_release_data': '2013-09-09',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'album_name': 'GUTS',
#   'album_release_data': '2023-09-08',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'},
#  {'album_id': '5MU0RmBSpoSxOPYBfcobDc',
#   'album_name': 'Prada',
#   'album_release_data': '2023-08-11',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5MU0RmBSpoSxOPYBfcobDc'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'album_name': "Harry's House",
#   'album_release_data': '2022-05-20',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'album_name': 'SOS',
#   'album_release_data': '2022-12-08',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#  {'album_id': '6PbnGueEO6LGodPfvNldYf',
#   'album_name': 'Zach Bryan',
#   'album_release_data': '2023-08-25',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/6PbnGueEO6LGodPfvNldYf'},
#  {'album_id': '52PtAAvfi8ZGTRK5c700y4',
#   'album_name': 'Colmillo De Leche',
#   'album_release_data': '2023-05-19',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/52PtAAvfi8ZGTRK5c700y4'},
#  {'album_id': '3WLJmMZUeDOuERFAk1Mxs6',
#   'album_name': 'Jawan',
#   'album_release_data': '2023-09-05',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/3WLJmMZUeDOuERFAk1Mxs6'},
#  {'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'album_name': 'GUTS',
#   'album_release_data': '2023-09-08',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'},
#  {'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'album_name': 'Starboy',
#   'album_release_data': '2016-11-25',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  {'album_id': '4x6cjOcVz44aiLSOHCLKPd',
#   'album_name': 'Que Onda',
#   'album_release_data': '2023-08-30',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/4x6cjOcVz44aiLSOHCLKPd'},
#  {'album_id': '5l0QlaI3wdZpE7ggoO5Rwg',
#   'album_name': 'Sprinter',
#   'album_release_data': '2023-06-01',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5l0QlaI3wdZpE7ggoO5Rwg'},
#  {'album_id': '1bBez9PNvkJPW08bU7NYta',
#   'album_name': 'Scarlet',
#   'album_release_data': '2023-09-20',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/1bBez9PNvkJPW08bU7NYta'},
#  {'album_id': '4DjJtllSDzVDBf7PYtsHaT',
#   'album_name': 'Slime You Out',
#   'album_release_data': '2023-09-15',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/4DjJtllSDzVDBf7PYtsHaT'},
#  {'album_id': '4jtQUtS4ABgER3DnGfKJCv',
#   'album_name': 'Classy 101',
#   'album_release_data': '2023-03-31',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/4jtQUtS4ABgER3DnGfKJCv'},
#  {'album_id': '3Fk8yQvPlCHgwR2pNhEIRA',
#   'album_name': 'Don Juan',
#   'album_release_data': '2023-08-25',
#   'album_total_tracks': 25,
#   'album_url': 'https://open.spotify.com/album/3Fk8yQvPlCHgwR2pNhEIRA'},
#  {'album_id': '7ixOAT89NSsgUITYc5ByB5',
#   'album_name': 'Layover',
#   'album_release_data': '2023-09-08',
#   'album_total_tracks': 6,
#   'album_url': 'https://open.spotify.com/album/7ixOAT89NSsgUITYc5ByB5'},
#  {'album_id': '42D6fdFJ4SLnh4jXZJrsNa',
#   'album_name': 'Holanda',
#   'album_release_data': '2023-07-28',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/42D6fdFJ4SLnh4jXZJrsNa'},
#  {'album_id': '5DvJgsMLbaR1HmAI6VhfcQ',
#   'album_name': 'Endless Summer Vacation',
#   'album_release_data': '2023-08-18',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/5DvJgsMLbaR1HmAI6VhfcQ'},
#  {'album_id': '2QJmrSgbdM35R67eoGQo4j',
#   'album_name': '1989',
#   'album_release_data': '2014-10-27',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'},
#  {'album_id': '2QJmrSgbdM35R67eoGQo4j',
#   'album_name': '1989',
#   'album_release_data': '2014-10-27',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'},
#  {'album_id': '72GhGik5fsSeFkgpjsllVj',
#   'album_name': 'UN PREVIEW',
#   'album_release_data': '2023-09-25',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/72GhGik5fsSeFkgpjsllVj'},
#  {'album_id': '4AdZV63ycxFLF6Hcol0QnB',
#   'album_name': 'Starboy',
#   'album_release_data': '2016-11-24',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#  {'album_id': '0FqAaUEyKCyUNFE1uQPZ7i',
#   'album_name': 'MAÑANA SERÁ BONITO (BICHOTA SEASON)',
#   'album_release_data': '2023-08-10',
#   'album_total_tracks': 9,
#   'album_url': 'https://open.spotify.com/album/0FqAaUEyKCyUNFE1uQPZ7i'},
#  {'album_id': '58ufpQsJ1DS5kq4hhzQDiI',
#   'album_name': 'Unorthodox Jukebox',
#   'album_release_data': '2012-12-07',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/58ufpQsJ1DS5kq4hhzQDiI'},
#  {'album_id': '5O0zUvdnJr0RbWzLFneN2i',
#   'album_name': 'Popular (Music from the HBO Original Series)',
#   'album_release_data': '2023-06-02',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5O0zUvdnJr0RbWzLFneN2i'},
#  {'album_id': '5V729UqvhwNOcMejx0m55I',
#   'album_name': "NewJeans 'Super Shy'",
#   'album_release_data': '2023-07-07',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/5V729UqvhwNOcMejx0m55I'},
#  {'album_id': '12v3LOTr03ykEMdyekvM1X',
#   'album_name': 'El Jefe',
#   'album_release_data': '2023-09-20',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/12v3LOTr03ykEMdyekvM1X'},
#  {'album_id': '0Gf1yE895FKK4YWVRuAeg8',
#   'album_name': 'Long Way Down (Deluxe)',
#   'album_release_data': '2013-06-24',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/0Gf1yE895FKK4YWVRuAeg8'},
#  {'album_id': '5i9lMMUZ1QZNsLEE3j50kT',
#   'album_name': 'El Comienzo',
#   'album_release_data': '2023-08-25',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/5i9lMMUZ1QZNsLEE3j50kT'},
#  {'album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'album_name': 'UTOPIA',
#   'album_release_data': '2023-07-28',
#   'album_total_tracks': 19,
#   'album_url': 'https://open.spotify.com/album/18NOKLkZETa4sWwLMIm0UZ'},
#  {'album_id': '5gCcb5fsSb6w5K8SyJrgtB',
#   'album_name': 'WHERE SHE GOES',
#   'album_release_data': '2023-05-18',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5gCcb5fsSb6w5K8SyJrgtB'},
#  {'album_id': '6aBVGuOUEuX18rHxyDWbti',
#   'album_name': 'La Bebe (Remix)',
#   'album_release_data': '2023-03-17',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/6aBVGuOUEuX18rHxyDWbti'},
#  {'album_id': '07w0rG5TETcyihsEIZR3qG',
#   'album_name': 'SOS',
#   'album_release_data': '2022-12-09',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/07w0rG5TETcyihsEIZR3qG'},
#  {'album_id': '0nayxjaX54Frd7GsZq6Pbs',
#   'album_name': 'Rave & Roses Ultra',
#   'album_release_data': '2023-04-27',
#   'album_total_tracks': 22,
#   'album_url': 'https://open.spotify.com/album/0nayxjaX54Frd7GsZq6Pbs'},
#  {'album_id': '151w1FgRZfnKZA9FEcg9Z3',
#   'album_name': 'Midnights',
#   'album_release_data': '2022-10-21',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/151w1FgRZfnKZA9FEcg9Z3'}]

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jbo7KFNMiIkfBR6ih0yhm'},
#   'href': 'https://api.spotify.com/v1/artists/0jbo7KFNMiIkfBR6ih0yhm',
#   'id': '0jbo7KFNMiIkfBR6ih0yhm',
#   'name': 'iñigo quintero',
#   'type': 'artist',
#   'uri': 'spotify:artist:0jbo7KFNMiIkfBR6ih0yhm'}]

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if(key=="track"):
            for artist in value['artists']:
                artist_dict = {'artist_name':artist['name'], 'artist_id':artist['id'], 'Eexternal_url':artist['href']}
                artist_list.append(artist_dict)
                
artist_list
# Out:
# [{'artist_name': 'iñigo quintero',
#   'artist_id': '0jbo7KFNMiIkfBR6ih0yhm',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/0jbo7KFNMiIkfBR6ih0yhm'},
#  {'artist_name': 'Tate McRae',
#   'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_name': 'Jung Kook',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc'},
#  {'artist_name': 'Latto',
#   'artist_id': '3MdXrJWsbVzdn6fe5JYkSQ',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ'},
#  {'artist_name': 'Bad Bunny',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_name': 'Bad Bunny',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_name': 'Feid',
#   'artist_id': '2LRoIwlKmHjgvigdNGBHNo',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo'},
#  {'artist_name': 'Doja Cat',
#   'artist_id': '5cj0lLjcoR7YOSnhnX0Po5',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5'},
#  {'artist_name': 'Taylor Swift',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_name': 'Kenya Grace',
#   'artist_id': '7uMDnSZyUYNBPLhPMNuaM2',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/7uMDnSZyUYNBPLhPMNuaM2'},
#  {'artist_name': 'Mitski',
#   'artist_id': '2uYWxilOVlUdk4oV9DvwqK',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK'},
#  {'artist_name': 'Jung Kook',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc'},
#  {'artist_name': 'Jack Harlow',
#   'artist_id': '2LIk90788K0zvyj2JJVwkJ',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/2LIk90788K0zvyj2JJVwkJ'},
#  {'artist_name': 'KAROL G',
#   'artist_id': '790FomKkXshlbRYZFtlgla',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_name': 'Peso Pluma',
#   'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_name': 'Tyla',
#   'artist_id': '3SozjO3Lat463tQICI9LcE',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/3SozjO3Lat463tQICI9LcE'},
#  {'artist_name': 'Myke Towers',
#   'artist_id': '7iK8PXO48WeuP03g8YR51W',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W'},
#  {'artist_name': 'The Kid LAROI',
#   'artist_id': '2tIP7SsRs7vjIcLrU85W8J',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/2tIP7SsRs7vjIcLrU85W8J'},
#  {'artist_name': 'Jung Kook',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc'},
#  {'artist_name': 'Central Cee',
#   'artist_id': '5H4yInM5zmHqpKIoMNAx4r',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/5H4yInM5zmHqpKIoMNAx4r'},
#  {'artist_name': 'Drake',
#   'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_name': 'Yeat',
#   'artist_id': '3qiHUAX7zY4Qnjx8TNUzVx',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/3qiHUAX7zY4Qnjx8TNUzVx'},
#  {'artist_name': 'Calle 24',
#   'artist_id': '6dLuQ5qXxIuWc5urxfIiZR',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/6dLuQ5qXxIuWc5urxfIiZR'},
#  {'artist_name': 'Chino Pacas',
#   'artist_id': '2rmkQLzj0k4nZdQehOUByO',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/2rmkQLzj0k4nZdQehOUByO'},
#  {'artist_name': 'Fuerza Regida',
#   'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_name': 'Maluma',
#   'artist_id': '1r4hJ1h58CWwUQe3MxPuau',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau'},
#  {'artist_name': 'Carin Leon',
#   'artist_id': '66ihevNkSYNzRAl44dx6jJ',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/66ihevNkSYNzRAl44dx6jJ'},
#  {'artist_name': 'Bad Bunny',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_name': 'Young Miko',
#   'artist_id': '3qsKSpcV3ncke3hw52JSMB',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/3qsKSpcV3ncke3hw52JSMB'},
#  {'artist_name': 'Darell',
#   'artist_id': '1TtXnWcUs0FCkaZDPGYHdf',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/1TtXnWcUs0FCkaZDPGYHdf'},
#  {'artist_name': 'Arctic Monkeys',
#   'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_name': 'Olivia Rodrigo',
#   'artist_id': '1McMsnEElThX1knmY4oliG',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_name': 'Peso Pluma',
#   'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_name': 'Gabito Ballesteros',
#   'artist_id': '6Sbl0NT50roqWvy746MfVf',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf'},
#  {'artist_name': 'Junior H',
#   'artist_id': '7Gi6gjaWy3DxyilpF1a8Is',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is'},
#  {'artist_name': 'David Kushner',
#   'artist_id': '33NVpKoXjItPwUJTMZIOiY',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/33NVpKoXjItPwUJTMZIOiY'},
#  {'artist_name': 'Taylor Swift',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_name': 'Billie Eilish',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_name': 'Doja Cat',
#   'artist_id': '5cj0lLjcoR7YOSnhnX0Po5',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5'},
#  {'artist_name': 'Taylor Swift',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_name': 'cassö',
#   'artist_id': '5wCmhq5J2hPwL2r0eKurxn',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/5wCmhq5J2hPwL2r0eKurxn'},
#  {'artist_name': 'RAYE',
#   'artist_id': '5KKpBU5eC2tJDzf0wmlRp2',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/5KKpBU5eC2tJDzf0wmlRp2'},
#  {'artist_name': 'D-Block Europe',
#   'artist_id': '5VadK1havLhK1OpKYsXv9y',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/5VadK1havLhK1OpKYsXv9y'},
#  {'artist_name': 'Harry Styles',
#   'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_name': 'Gunna',
#   'artist_id': '2hlmm7s2ICUX0LVIhVFlZQ',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/2hlmm7s2ICUX0LVIhVFlZQ'},
#  {'artist_name': 'The Weeknd',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_name': 'Daft Punk',
#   'artist_id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi'},
#  {'artist_name': 'SZA',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_name': 'Dua Lipa',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_name': 'Troye Sivan',
#   'artist_id': '3WGpXCj9YhhfX11TToZcXP',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/3WGpXCj9YhhfX11TToZcXP'},
#  {'artist_name': 'Bad Bunny',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_name': 'Drake',
#   'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_name': 'J. Cole',
#   'artist_id': '6l3HvQ5sa6mXTsMTB19rO5',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5'},
#  {'artist_name': 'Bad Bunny',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_name': 'Mora',
#   'artist_id': '0Q8NcsJwoCbZOHHW63su5S',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/0Q8NcsJwoCbZOHHW63su5S'},
#  {'artist_name': 'Quevedo',
#   'artist_id': '52iwsT98xCoGgiGntTiR7K',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/52iwsT98xCoGgiGntTiR7K'},
#  {'artist_name': 'Zach Bryan',
#   'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/40ZNYROS4zLfyyBSs2PGe2'},
#  {'artist_name': 'Kacey Musgraves',
#   'artist_id': '70kkdajctXSbqSMJbQO424',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/70kkdajctXSbqSMJbQO424'},
#  {'artist_name': 'Taylor Swift',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_name': 'The Weeknd',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_name': 'Tom Odell',
#   'artist_id': '2txHhyCwHjUEpJjWrEyqyX',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/2txHhyCwHjUEpJjWrEyqyX'},
#  {'artist_name': 'Bizarrap',
#   'artist_id': '716NhGYqD1jl2wI1Qkgq36',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36'},
#  {'artist_name': 'Milo j',
#   'artist_id': '19HM5j0ULGSmEoRcrSe5x3',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3'},
#  {'artist_name': 'The Neighbourhood',
#   'artist_id': '77SW9BnxLY8rJ0RciFqkHh',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/77SW9BnxLY8rJ0RciFqkHh'},
#  {'artist_name': 'Taylor Swift',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_name': 'Carin Leon',
#   'artist_id': '66ihevNkSYNzRAl44dx6jJ',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/66ihevNkSYNzRAl44dx6jJ'},
#  {'artist_name': 'Bizarrap',
#   'artist_id': '716NhGYqD1jl2wI1Qkgq36',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36'},
#  {'artist_name': 'Milo j',
#   'artist_id': '19HM5j0ULGSmEoRcrSe5x3',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3'},
#  {'artist_name': 'Miley Cyrus',
#   'artist_id': '5YGY8feqx7naU7z4HrwZM6',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6'},
#  {'artist_name': 'Taylor Swift',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_name': 'SZA',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'Eexternal_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'}]

# %%
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jbo7KFNMiIkfBR6ih0yhm'},
#     'href': 'https://api.spotify.com/v1/artists/0jbo7KFNMiIkfBR6ih0yhm',
#     'id': '0jbo7KFNMiIkfBR6ih0yhm',
#     'name': 'iñigo quintero',
#     'type': 'artist',
#     'uri': 'spotify:artist:0jbo7KFNMiIkfBR6ih0yhm'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/66k6EGkPtYoN44anGIsEPW'},
#   'href': 'https://api.spotify.com/v1/albums/66k6EGkPtYoN44anGIsEPW',
#   'id': '66k6EGkPtYoN44anGIsEPW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735cb9531348f45311cd6fb8df',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025cb9531348f45311cd6fb8df',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515cb9531348f45311cd6fb8df',
#     'width': 64}],
#   'name': 'Si No Estás',
#   'release_date': '2022-09-23',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:66k6EGkPtYoN44anGIsEPW'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jbo7KFNMiIkfBR6ih0yhm'},
#    'href': 'https://api.spotify.com/v1/artists/0jbo7KFNMiIkfBR6ih0yhm',
#    'id': '0jbo7KFNMiIkfBR6ih0yhm',
#    'name': 'iñigo quintero',
#    'type': 'artist',
#    'uri': 'spotify:artist:0jbo7KFNMiIkfBR6ih0yhm'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 184061,
#  'episode': False,
#  'explicit': False,
#  'external_ids': {'isrc': 'TCAGM2208561'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2HafqoJbgXdtjwCOvNEF14'},
#  'href': 'https://api.spotify.com/v1/tracks/2HafqoJbgXdtjwCOvNEF14',
#  'id': '2HafqoJbgXdtjwCOvNEF14',
#  'is_local': False,
#  'name': 'Si No Estás',
#  'popularity': 98,
#  'preview_url': 'https://p.scdn.co/mp3-preview/28d6d99074f2f2d7e70597d3213099ca04e75116?cid=7bc584d74534470091c4d94b3298bb5c',
#  'track': True,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:2HafqoJbgXdtjwCOvNEF14'}

# %%
data['items'][0]['track']['name']
# Out:
# 'Si No Estás'

# %%
data['items'][0]['track']['id']
# Out:
# '2HafqoJbgXdtjwCOvNEF14'

# %%
data['items'][0]['track']['duration_ms']
# Out:
# 184061

# %%
data['items'][0]['track']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/track/2HafqoJbgXdtjwCOvNEF14'

# %%
data['items'][0]['track']['popularity']
# Out:
# 98

# %%
data['items'][0]['added_at']
# Out:
# '2023-10-27T08:45:25Z'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '66k6EGkPtYoN44anGIsEPW'

# %%
data['items'][0]['track']['album']['artists'][0]['id']
# Out:
# '0jbo7KFNMiIkfBR6ih0yhm'

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id, 'song_name':song_name, 'song_duration':song_duration, 'song_url':song_url, 'song_popularity':song_popularity,
                   'song_added':song_added, 'album_id':album_id, 'artist_id':artist_id}
    song_list.append(song_element)

song_list
# Out:
# [{'song_id': '2HafqoJbgXdtjwCOvNEF14',
#   'song_name': 'Si No Estás',
#   'song_duration': 184061,
#   'song_url': 'https://open.spotify.com/track/2HafqoJbgXdtjwCOvNEF14',
#   'song_popularity': 98,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '66k6EGkPtYoN44anGIsEPW',
#   'artist_id': '0jbo7KFNMiIkfBR6ih0yhm'},
#  {'song_id': '3rUGC1vUpkDG9CZFHMur1t',
#   'song_name': 'greedy',
#   'song_duration': 131872,
#   'song_url': 'https://open.spotify.com/track/3rUGC1vUpkDG9CZFHMur1t',
#   'song_popularity': 99,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'artist_id': '45dkTj5sMRSjrmBSBeiHym'},
#  {'song_id': '7x9aauaA9cu6tyfpHnqDLo',
#   'song_name': 'Seven (feat. Latto) (Explicit Ver.)',
#   'song_duration': 184400,
#   'song_url': 'https://open.spotify.com/track/7x9aauaA9cu6tyfpHnqDLo',
#   'song_popularity': 97,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '53985D8g3JcGBoULSOYYKX',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc'},
#  {'song_id': '4MjDJD8cW7iVeWInc2Bdyj',
#   'song_name': 'MONACO',
#   'song_duration': 267194,
#   'song_url': 'https://open.spotify.com/track/4MjDJD8cW7iVeWInc2Bdyj',
#   'song_popularity': 97,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4FftCsAcXXD1nFO9RFUNFO',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '7iQXYTyuG13aoeHxGG28Nh',
#   'song_name': 'PERRO NEGRO',
#   'song_duration': 162767,
#   'song_url': 'https://open.spotify.com/track/7iQXYTyuG13aoeHxGG28Nh',
#   'song_popularity': 96,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4FftCsAcXXD1nFO9RFUNFO',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '56y1jOTK0XSvJzVv9vHQBK',
#   'song_name': 'Paint The Town Red',
#   'song_duration': 230480,
#   'song_url': 'https://open.spotify.com/track/56y1jOTK0XSvJzVv9vHQBK',
#   'song_popularity': 89,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '1bBez9PNvkJPW08bU7NYta',
#   'artist_id': '5cj0lLjcoR7YOSnhnX0Po5'},
#  {'song_id': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'song_name': 'Cruel Summer',
#   'song_duration': 178426,
#   'song_url': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr',
#   'song_popularity': 100,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '5mjYQaktjmjcMKcUIcqz4s',
#   'song_name': 'Strangers',
#   'song_duration': 172964,
#   'song_url': 'https://open.spotify.com/track/5mjYQaktjmjcMKcUIcqz4s',
#   'song_popularity': 98,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '18ogtNq9F7DmMkNYO6Xb4k',
#   'artist_id': '7uMDnSZyUYNBPLhPMNuaM2'},
#  {'song_id': '3vkCueOmm7xQDoJ17W1Pm3',
#   'song_name': 'My Love Mine All Mine',
#   'song_duration': 137773,
#   'song_url': 'https://open.spotify.com/track/3vkCueOmm7xQDoJ17W1Pm3',
#   'song_popularity': 96,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '2Cn1d2KgbkAqbZCJ1RzdkA',
#   'artist_id': '2uYWxilOVlUdk4oV9DvwqK'},
#  {'song_id': '01qFKNWq73UfEslI0GvumE',
#   'song_name': '3D (feat. Jack Harlow)',
#   'song_duration': 201812,
#   'song_url': 'https://open.spotify.com/track/01qFKNWq73UfEslI0GvumE',
#   'song_popularity': 89,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '0fJ0beklzFwoBv01U8792s',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc'},
#  {'song_id': '5RqSsdzTNPX1uzkmlHCFvK',
#   'song_name': 'QLONA',
#   'song_duration': 172797,
#   'song_url': 'https://open.spotify.com/track/5RqSsdzTNPX1uzkmlHCFvK',
#   'song_popularity': 94,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '0FqAaUEyKCyUNFE1uQPZ7i',
#   'artist_id': '790FomKkXshlbRYZFtlgla'},
#  {'song_id': '5aIVCx5tnk0ntmdiinnYvw',
#   'song_name': 'Water',
#   'song_duration': 200255,
#   'song_url': 'https://open.spotify.com/track/5aIVCx5tnk0ntmdiinnYvw',
#   'song_popularity': 94,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '22sXXkKgjEuawIFL1e1tRw',
#   'artist_id': '3SozjO3Lat463tQICI9LcE'},
#  {'song_id': '7ABLbnD53cQK00mhcaOUVG',
#   'song_name': 'LALA',
#   'song_duration': 197920,
#   'song_url': 'https://open.spotify.com/track/7ABLbnD53cQK00mhcaOUVG',
#   'song_popularity': 97,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '3puAvurwvtvi1rodndIPW8',
#   'artist_id': '7iK8PXO48WeuP03g8YR51W'},
#  {'song_id': '0rKWJnmo6Q0ovoPOLoLm0t',
#   'song_name': 'TOO MUCH',
#   'song_duration': 203894,
#   'song_url': 'https://open.spotify.com/track/0rKWJnmo6Q0ovoPOLoLm0t',
#   'song_popularity': 91,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '7gCggwpSuqUmVzWniLdpKR',
#   'artist_id': '2tIP7SsRs7vjIcLrU85W8J'},
#  {'song_id': '2YSzYUF3jWqb9YP9VXmpjE',
#   'song_name': 'IDGAF (feat. Yeat)',
#   'song_duration': 260111,
#   'song_url': 'https://open.spotify.com/track/2YSzYUF3jWqb9YP9VXmpjE',
#   'song_popularity': 94,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4czdORdCWP9umpbhFXK2fW',
#   'artist_id': '3TVXtAsR1Inumwj472S9r4'},
#  {'song_id': '6uIIdjYTxxpWOyWuVXrKQO',
#   'song_name': 'Que Onda',
#   'song_duration': 191466,
#   'song_url': 'https://open.spotify.com/track/6uIIdjYTxxpWOyWuVXrKQO',
#   'song_popularity': 94,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4x6cjOcVz44aiLSOHCLKPd',
#   'artist_id': '6dLuQ5qXxIuWc5urxfIiZR'},
#  {'song_id': '4bw8mcDUSRWfQo63ZTYRnU',
#   'song_name': 'Según Quién',
#   'song_duration': 142334,
#   'song_url': 'https://open.spotify.com/track/4bw8mcDUSRWfQo63ZTYRnU',
#   'song_popularity': 88,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '3Fk8yQvPlCHgwR2pNhEIRA',
#   'artist_id': '1r4hJ1h58CWwUQe3MxPuau'},
#  {'song_id': '3nNmRE0DxHC6ZaKkrpUumS',
#   'song_name': 'FINA',
#   'song_duration': 216327,
#   'song_url': 'https://open.spotify.com/track/3nNmRE0DxHC6ZaKkrpUumS',
#   'song_popularity': 93,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4FftCsAcXXD1nFO9RFUNFO',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '3cDyocF0Ibdfs1SFQk5cLZ',
#   'song_name': 'Lollipop',
#   'song_duration': 199946,
#   'song_url': 'https://open.spotify.com/track/3cDyocF0Ibdfs1SFQk5cLZ',
#   'song_popularity': 92,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '11UJfH39O0VqLiQGLW0D0e',
#   'artist_id': '1TtXnWcUs0FCkaZDPGYHdf'},
#  {'song_id': '5XeFesFbtLpXzIVDNQP22n',
#   'song_name': 'I Wanna Be Yours',
#   'song_duration': 183956,
#   'song_url': 'https://open.spotify.com/track/5XeFesFbtLpXzIVDNQP22n',
#   'song_popularity': 95,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '78bpIziExqiI9qztvNFlQu',
#   'artist_id': '7Ln80lUS6He07XvHI8qqHH'},
#  {'song_id': '1kuGVB7EU95pJObxwvfwKS',
#   'song_name': 'vampire',
#   'song_duration': 219724,
#   'song_url': 'https://open.spotify.com/track/1kuGVB7EU95pJObxwvfwKS',
#   'song_popularity': 96,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '7mXuWTczZNxG5EDcjFEuJR',
#   'song_name': 'LADY GAGA',
#   'song_duration': 212878,
#   'song_url': 'https://open.spotify.com/track/7mXuWTczZNxG5EDcjFEuJR',
#   'song_popularity': 95,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4jox3ip1I39DFC2B7R5qLH',
#   'artist_id': '12GqGscKJx3aE4t07u7eVZ'},
#  {'song_id': '1odExI7RdWc4BT515LTAwj',
#   'song_name': 'Daylight',
#   'song_duration': 212953,
#   'song_url': 'https://open.spotify.com/track/1odExI7RdWc4BT515LTAwj',
#   'song_popularity': 95,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '6NcI39WPu4kY6Tul11nhSv',
#   'artist_id': '33NVpKoXjItPwUJTMZIOiY'},
#  {'song_id': '4lIxdJw6W3Fg4vUIYCB0S5',
#   'song_name': 'Style',
#   'song_duration': 231000,
#   'song_url': 'https://open.spotify.com/track/4lIxdJw6W3Fg4vUIYCB0S5',
#   'song_popularity': 83,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '2QJmrSgbdM35R67eoGQo4j',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '6wf7Yu7cxBSPrRlWeSeK0Q',
#   'song_name': 'What Was I Made For? [From The Motion Picture "Barbie"]',
#   'song_duration': 222369,
#   'song_url': 'https://open.spotify.com/track/6wf7Yu7cxBSPrRlWeSeK0Q',
#   'song_popularity': 96,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '3AafSrFIbJPH6BJHiJm1Cd',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '5PyDJG7SQRgWXefgexqIge',
#   'song_name': 'Agora Hills',
#   'song_duration': 265360,
#   'song_url': 'https://open.spotify.com/track/5PyDJG7SQRgWXefgexqIge',
#   'song_popularity': 80,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '1bBez9PNvkJPW08bU7NYta',
#   'artist_id': '5cj0lLjcoR7YOSnhnX0Po5'},
#  {'song_id': '1p80LdxRV74UKvL8gnD7ky',
#   'song_name': 'Blank Space',
#   'song_duration': 231826,
#   'song_url': 'https://open.spotify.com/track/1p80LdxRV74UKvL8gnD7ky',
#   'song_popularity': 83,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '2QJmrSgbdM35R67eoGQo4j',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '59NraMJsLaMCVtwXTSia8i',
#   'song_name': 'Prada',
#   'song_duration': 132359,
#   'song_url': 'https://open.spotify.com/track/59NraMJsLaMCVtwXTSia8i',
#   'song_popularity': 94,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '5MU0RmBSpoSxOPYBfcobDc',
#   'artist_id': '5wCmhq5J2hPwL2r0eKurxn'},
#  {'song_id': '4Dvkj6JhhA12EX05fT7y2e',
#   'song_name': 'As It Was',
#   'song_duration': 167303,
#   'song_url': 'https://open.spotify.com/track/4Dvkj6JhhA12EX05fT7y2e',
#   'song_popularity': 95,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'artist_id': '6KImCVD70vtIoJWnq6nGn3'},
#  {'song_id': '4rXLjWdF2ZZpXCVTfWcshS',
#   'song_name': 'fukumean',
#   'song_duration': 125040,
#   'song_url': 'https://open.spotify.com/track/4rXLjWdF2ZZpXCVTfWcshS',
#   'song_popularity': 95,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '5qmZefgh78fN3jsyPPlvuw',
#   'artist_id': '2hlmm7s2ICUX0LVIhVFlZQ'},
#  {'song_id': '7MXVkk9YMctZqd1Srtv4MB',
#   'song_name': 'Starboy',
#   'song_duration': 230453,
#   'song_url': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB',
#   'song_popularity': 94,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '1Qrg8KqiBpW07V7PNxwwwL',
#   'song_name': 'Kill Bill',
#   'song_duration': 153946,
#   'song_url': 'https://open.spotify.com/track/1Qrg8KqiBpW07V7PNxwwwL',
#   'song_popularity': 92,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'},
#  {'song_id': '1vYXt7VSjH9JIM5oRRo7vA',
#   'song_name': 'Dance The Night - From Barbie The Album',
#   'song_duration': 176579,
#   'song_url': 'https://open.spotify.com/track/1vYXt7VSjH9JIM5oRRo7vA',
#   'song_popularity': 94,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '5cH7FqB7JD5q1tJXJ7FHYu',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we'},
#  {'song_id': '5Eh1nj7IjV9lwpcKAkidyY',
#   'song_name': 'One Of Your Girls',
#   'song_duration': 181481,
#   'song_url': 'https://open.spotify.com/track/5Eh1nj7IjV9lwpcKAkidyY',
#   'song_popularity': 87,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '5UcGyEltve5psjxSRsHx8E',
#   'artist_id': '3WGpXCj9YhhfX11TToZcXP'},
#  {'song_id': '5ixdmTpCmH5diBA1j154wN',
#   'song_name': 'UN PREVIEW',
#   'song_duration': 165582,
#   'song_url': 'https://open.spotify.com/track/5ixdmTpCmH5diBA1j154wN',
#   'song_popularity': 87,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4FftCsAcXXD1nFO9RFUNFO',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '7aqfrAY2p9BUSiupwk3svU',
#   'song_name': 'First Person Shooter (feat. J. Cole)',
#   'song_duration': 247444,
#   'song_url': 'https://open.spotify.com/track/7aqfrAY2p9BUSiupwk3svU',
#   'song_popularity': 92,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4czdORdCWP9umpbhFXK2fW',
#   'artist_id': '3TVXtAsR1Inumwj472S9r4'},
#  {'song_id': '4qSEvFGCpde73gqIuq3sho',
#   'song_name': 'HIBIKI',
#   'song_duration': 208000,
#   'song_url': 'https://open.spotify.com/track/4qSEvFGCpde73gqIuq3sho',
#   'song_popularity': 92,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4FftCsAcXXD1nFO9RFUNFO',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '6XbtvPmIpyCbjuT0e8cQtp',
#   'song_name': 'Columbia',
#   'song_duration': 186000,
#   'song_url': 'https://open.spotify.com/track/6XbtvPmIpyCbjuT0e8cQtp',
#   'song_popularity': 95,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '07kam1Dks7GIucbSelfvyX',
#   'artist_id': '52iwsT98xCoGgiGntTiR7K'},
#  {'song_id': '4KULAymBBJcPRpk1yO4dOG',
#   'song_name': 'I Remember Everything (feat. Kacey Musgraves)',
#   'song_duration': 227195,
#   'song_url': 'https://open.spotify.com/track/4KULAymBBJcPRpk1yO4dOG',
#   'song_popularity': 93,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '6PbnGueEO6LGodPfvNldYf',
#   'artist_id': '40ZNYROS4zLfyyBSs2PGe2'},
#  {'song_id': '0V3wPSX9ygBnCm8psDIegu',
#   'song_name': 'Anti-Hero',
#   'song_duration': 200690,
#   'song_url': 'https://open.spotify.com/track/0V3wPSX9ygBnCm8psDIegu',
#   'song_popularity': 93,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '151w1FgRZfnKZA9FEcg9Z3',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '2LBqCSwhJGcFQeTHMVGwy3',
#   'song_name': 'Die For You',
#   'song_duration': 260253,
#   'song_url': 'https://open.spotify.com/track/2LBqCSwhJGcFQeTHMVGwy3',
#   'song_popularity': 90,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4AdZV63ycxFLF6Hcol0QnB',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '3JvKfv6T31zO0ini8iNItO',
#   'song_name': 'Another Love',
#   'song_duration': 244360,
#   'song_url': 'https://open.spotify.com/track/3JvKfv6T31zO0ini8iNItO',
#   'song_popularity': 92,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '0Gf1yE895FKK4YWVRuAeg8',
#   'artist_id': '2txHhyCwHjUEpJjWrEyqyX'},
#  {'song_id': '4SW9gHnW8NfKOdqmh0ij45',
#   'song_name': 'Fruto',
#   'song_duration': 132294,
#   'song_url': 'https://open.spotify.com/track/4SW9gHnW8NfKOdqmh0ij45',
#   'song_popularity': 91,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4NMv3cMkDwkkR6EdLloQDB',
#   'artist_id': '716NhGYqD1jl2wI1Qkgq36'},
#  {'song_id': '2QjOHCTQ1Jl3zawyYOpxh6',
#   'song_name': 'Sweater Weather',
#   'song_duration': 240400,
#   'song_url': 'https://open.spotify.com/track/2QjOHCTQ1Jl3zawyYOpxh6',
#   'song_popularity': 93,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'artist_id': '77SW9BnxLY8rJ0RciFqkHh'},
#  {'song_id': '1dGr1c8CrMLDpV6mPbImSI',
#   'song_name': 'Lover',
#   'song_duration': 221306,
#   'song_url': 'https://open.spotify.com/track/1dGr1c8CrMLDpV6mPbImSI',
#   'song_popularity': 92,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '25OeKzcqakFPaJlXHPE5lm',
#   'song_name': 'Primera Cita',
#   'song_duration': 186455,
#   'song_url': 'https://open.spotify.com/track/25OeKzcqakFPaJlXHPE5lm',
#   'song_popularity': 87,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '52PtAAvfi8ZGTRK5c700y4',
#   'artist_id': '66ihevNkSYNzRAl44dx6jJ'},
#  {'song_id': '1iLbUmb2b2btyAAcQ68a1p',
#   'song_name': 'Milo J: Bzrp Music Sessions, Vol. 57',
#   'song_duration': 189901,
#   'song_url': 'https://open.spotify.com/track/1iLbUmb2b2btyAAcQ68a1p',
#   'song_popularity': 89,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '5NwbUP5QkkMndzwJp9kkxr',
#   'artist_id': '716NhGYqD1jl2wI1Qkgq36'},
#  {'song_id': '7DSAEUvxU8FajXtRloy8M0',
#   'song_name': 'Flowers',
#   'song_duration': 200600,
#   'song_url': 'https://open.spotify.com/track/7DSAEUvxU8FajXtRloy8M0',
#   'song_popularity': 92,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '5DvJgsMLbaR1HmAI6VhfcQ',
#   'artist_id': '5YGY8feqx7naU7z4HrwZM6'},
#  {'song_id': '3hUxzQpSfdDqwM3ZTFQY0K',
#   'song_name': 'august',
#   'song_duration': 261922,
#   'song_url': 'https://open.spotify.com/track/3hUxzQpSfdDqwM3ZTFQY0K',
#   'song_popularity': 92,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '2fenSS68JI1h4Fo296JfGr',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '4iZ4pt7kvcaH6Yo8UoZ4s2',
#   'song_name': 'Snooze',
#   'song_duration': 201800,
#   'song_url': 'https://open.spotify.com/track/4iZ4pt7kvcaH6Yo8UoZ4s2',
#   'song_popularity': 92,
#   'song_added': '2023-10-27T08:45:25Z',
#   'album_id': '07w0rG5TETcyihsEIZR3qG',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'}]

# %%
pip install pandas
# Out:
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/f0/9b/f5218b4d746491bf262f74665f17604de88387173127ce0ed1eabcddf754/pandas-2.1.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading pandas-2.1.2-cp312-cp312-win_amd64.whl.metadata (18 kB)
# Collecting numpy<2,>=1.26.0 (from pandas)
#   Obtaining dependency information for numpy<2,>=1.26.0 from https://files.pythonhosted.org/packages/32/95/908d0caa051beae4f7c77652dbbeb781e7b717f3040c5c5fcaed4d3ed08f/numpy-1.26.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading numpy-1.26.1-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.2 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 61.2/61.2 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\uday\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ------------------------------------- 341.8/341.8 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\uday\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.1.2-cp312-cp312-win_amd64.whl (10.5 MB)
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/10.5 MB 31.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.3/10.5 MB 17.1 MB/s eta 0:00:01
#    ------ --------------------------------- 1.7/10.5 MB 13.7 MB/s eta 0:00:01
#    ------- -------------------------------- 2.0/10.5 MB 11.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.3/10.5 MB 10.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.7/10.5 MB 10.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.1/10.5 MB 9.8 MB/s eta 0:00:01
#    ------------ --------------------------- 3.3/10.5 MB 9.1 MB/s eta 0:00:01
#    ------------- -------------------------- 3.5/10.5 MB 8.5 MB/s eta 0:00:01
#    ------------- -------------------------- 3.7/10.5 MB 8.1 MB/s eta 0:00:01
#    -------------- ------------------------- 3.9/10.5 MB 7.7 MB/s eta 0:00:01
#    --------------- ------------------------ 4.1/10.5 MB 7.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.3/10.5 MB 7.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.5/10.5 MB 7.1 MB/s eta 0:00:01
#    ------------------ --------------------- 4.8/10.5 MB 7.0 MB/s eta 0:00:01
#    ------------------- -------------------- 5.1/10.5 MB 6.9 MB/s eta 0:00:01
#    ------------------- -------------------- 5.1/10.5 MB 6.9 MB/s eta 0:00:01
#    --------------------- ------------------ 5.8/10.5 MB 7.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.1/10.5 MB 7.0 MB/s eta 0:00:01
#    ------------------------ --------------- 6.5/10.5 MB 7.0 MB/s eta 0:00:01
#    -------------------------- ------------- 6.9/10.5 MB 7.1 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.5 MB 7.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.7/10.5 MB 7.3 MB/s eta 0:00:01
#    ------------------------------ --------- 8.1/10.5 MB 7.3 MB/s eta 0:00:01
#    -------------------------------- ------- 8.4/10.5 MB 7.3 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.5 MB 7.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.8/10.5 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.0/10.5 MB 7.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.2/10.5 MB 6.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.5 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 9.9/10.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------------- - 10.2/10.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.5/10.5 MB 6.2 MB/s eta 0:00:00
# Downloading numpy-1.26.1-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/15.5 MB 7.6 MB/s eta 0:00:03
#    - -------------------------------------- 0.6/15.5 MB 7.5 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/15.5 MB 7.5 MB/s eta 0:00:02
#    --- ------------------------------------ 1.3/15.5 MB 7.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.7/15.5 MB 8.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.1/15.5 MB 8.3 MB/s eta 0:00:02
#    ------ --------------------------------- 2.5/15.5 MB 8.5 MB/s eta 0:00:02
#    ------- -------------------------------- 3.0/15.5 MB 8.7 MB/s eta 0:00:02
#    -------- ------------------------------- 3.5/15.5 MB 8.8 MB/s eta 0:00:02
#    --------- ------------------------------ 3.9/15.5 MB 8.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/15.5 MB 8.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.4/15.5 MB 8.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.6/15.5 MB 7.9 MB/s eta 0:00:02
#    ------------ --------------------------- 4.7/15.5 MB 7.6 MB/s eta 0:00:02
#    ------------ --------------------------- 4.9/15.5 MB 7.3 MB/s eta 0:00:02
#    ------------ --------------------------- 5.0/15.5 MB 7.0 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.5 MB 6.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.4/15.5 MB 6.6 MB/s eta 0:00:02
#    -------------- ------------------------- 5.6/15.5 MB 6.5 MB/s eta 0:00:02
#    --------------- ------------------------ 5.9/15.5 MB 6.5 MB/s eta 0:00:02
#    --------------- ------------------------ 6.1/15.5 MB 6.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.4/15.5 MB 6.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.7/15.5 MB 6.4 MB/s eta 0:00:02
#    ------------------ --------------------- 7.0/15.5 MB 6.4 MB/s eta 0:00:02
#    ------------------ --------------------- 7.4/15.5 MB 6.4 MB/s eta 0:00:02
#    ------------------- -------------------- 7.7/15.5 MB 6.5 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/15.5 MB 6.5 MB/s eta 0:00:02
#    --------------------- ------------------ 8.5/15.5 MB 6.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.9/15.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------ --------------- 9.3/15.5 MB 6.8 MB/s eta 0:00:01
#    ------------------------- -------------- 9.7/15.5 MB 6.9 MB/s eta 0:00:01
#    -------------------------- ------------- 10.1/15.5 MB 6.9 MB/s eta 0:00:01
#    -------------------------- ------------- 10.4/15.5 MB 6.9 MB/s eta 0:00:01
#    --------------------------- ------------ 10.6/15.5 MB 6.8 MB/s eta 0:00:01
#    --------------------------- ------------ 10.8/15.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.9/15.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.0/15.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.2/15.5 MB 6.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.4/15.5 MB 6.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.5 MB 6.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.5 MB 6.2 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.5 MB 6.1 MB/s eta 0:00:01
#    ------------------------------- -------- 12.3/15.5 MB 6.0 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 5.9 MB/s eta 0:00:01
#    --------------------------------- ------ 12.9/15.5 MB 5.8 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.5 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.4/15.5 MB 5.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 14.0/15.5 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.5 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 14.8/15.5 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.5 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 5.4 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ---------------------------------------- 0.0/502.5 kB ? eta -:--:--
#    ----------------------------------- ---- 440.3/502.5 kB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 502.5/502.5 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.1 pandas-2.1.2 pytz-2023.3.post1 tzdata-2023.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                           album_name  \
# 0  66k6EGkPtYoN44anGIsEPW                          Si No Estás
# 1  3UOV8XvCwMKaATRNXrYCjN                               greedy
# 2  53985D8g3JcGBoULSOYYKX                  Seven (feat. Latto)
# 3  4FftCsAcXXD1nFO9RFUNFO  nadie sabe lo que va a pasar mañana
# 4  4FftCsAcXXD1nFO9RFUNFO  nadie sabe lo que va a pasar mañana
#
#   album_release_data  album_total_tracks  \
# 0         2022-09-23                   1
# 1         2023-09-15                   1
# 2         2023-07-14                   3
# 3         2023-10-13                  22
# 4         2023-10-13                  22
#
#                                            album_url
# 0  https://open.spotify.com/album/66k6EGkPtYoN44a...
# 1  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 2  https://open.spotify.com/album/53985D8g3JcGBoU...
# 3  https://open.spotify.com/album/4FftCsAcXXD1nFO...
# 4  https://open.spotify.com/album/4FftCsAcXXD1nFO...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#       artist_name               artist_id  \
# 0  iñigo quintero  0jbo7KFNMiIkfBR6ih0yhm
# 1      Tate McRae  45dkTj5sMRSjrmBSBeiHym
# 2       Jung Kook  6HaGTQPmzraVmaVxvz6EUc
# 3           Latto  3MdXrJWsbVzdn6fe5JYkSQ
# 4       Bad Bunny  4q3ewBCX7sLwd24euuV69X
#
#                                        Eexternal_url
# 0  https://api.spotify.com/v1/artists/0jbo7KFNMiI...
# 1  https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 2  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 3  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 4  https://api.spotify.com/v1/artists/4q3ewBCX7sL...

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   56y1jOTK0XSvJzVv9vHQBK                                 Paint The Town Red
# 1   7x9aauaA9cu6tyfpHnqDLo                Seven (feat. Latto) (Explicit Ver.)
# 2   1BxfuPKGuaTgP7aM0Bbdwr                                       Cruel Summer
# 3   5mjYQaktjmjcMKcUIcqz4s                                          Strangers
# 4   5RqSsdzTNPX1uzkmlHCFvK                                              QLONA
# 5   3rUGC1vUpkDG9CZFHMur1t                                             greedy
# 6   7ABLbnD53cQK00mhcaOUVG                                               LALA
# 7   1kuGVB7EU95pJObxwvfwKS                                            vampire
# 8   6XbtvPmIpyCbjuT0e8cQtp                                           Columbia
# 9   7mXuWTczZNxG5EDcjFEuJR                                          LADY GAGA
# 10  6wf7Yu7cxBSPrRlWeSeK0Q  What Was I Made For? [From The Motion Picture ...
# 11  1vYXt7VSjH9JIM5oRRo7vA            Dance The Night - From Barbie The Album
# 12  4rXLjWdF2ZZpXCVTfWcshS                                           fukumean
# 13  1odExI7RdWc4BT515LTAwj                                           Daylight
# 14  5XeFesFbtLpXzIVDNQP22n                                   I Wanna Be Yours
# 15  3IX0yuEVvDbnqUwMBB3ouC                                    bad idea right?
# 16  59NraMJsLaMCVtwXTSia8i                                              Prada
# 17  4Dvkj6JhhA12EX05fT7y2e                                          As It Was
# 18  1Qrg8KqiBpW07V7PNxwwwL                                          Kill Bill
# 19  4KULAymBBJcPRpk1yO4dOG      I Remember Everything (feat. Kacey Musgraves)
# 20  25OeKzcqakFPaJlXHPE5lm                                       Primera Cita
# 21  3xMHXmedL5Rvfxmiar9Ryv                                            Chaleya
# 22  2gyxAWHebV7xPYVxqoi86f                                      get him back!
# 23  7MXVkk9YMctZqd1Srtv4MB                                            Starboy
# 24  6uIIdjYTxxpWOyWuVXrKQO                                           Que Onda
# 25  2FDTHlrBguDzQkp7PVj16Q                                           Sprinter
# 26  5PyDJG7SQRgWXefgexqIge                                        Agora Hills
# 27  3RaCGXCiiMufRPoexXxGkV                          Slime You Out (feat. SZA)
# 28  6XSqqQIy7Lm7SnwxS4NrGx                                         Classy 101
# 29  4bw8mcDUSRWfQo63ZTYRnU                                        Según Quién
# 30  5h1BN75CEh8wdSwE1xrbSe                                       Slow Dancing
# 31  6irysuQyZWd7Bjj7ePiOs2                                            Holanda
# 32  7DSAEUvxU8FajXtRloy8M0                                            Flowers
# 33  4lIxdJw6W3Fg4vUIYCB0S5                                              Style
# 34  1p80LdxRV74UKvL8gnD7ky                                        Blank Space
# 35  63ui2w3QJBp8xx0c1MJB2Z                                         UN PREVIEW
# 36  2LBqCSwhJGcFQeTHMVGwy3                                        Die For You
# 37  54zcJnb3tp9c5OVKREZ1Is                                  MI EX TENÍA RAZÓN
# 38  3w3y8KPTfNeOKPiqUTakBh                               Locked out of Heaven
# 39  6WzRpISELf3YglGAh7TXcG  Popular (with Playboi Carti & Madonna) - Music...
# 40  5sdQOyqq2IDhvmx2lHOpwd                                          Super Shy
# 41  5wjsJIUf6pdrwauPDae43o                                            El Jefe
# 42  3JvKfv6T31zO0ini8iNItO                                       Another Love
# 43  2yzshFeBIwH8tWIqHEFLeD                                          un x100to
# 44  6wsqVwoiVH2kde4k4KKAFU                                           I KNOW ?
# 45  7ro0hRteUMfnOioTFI5TG1                                     WHERE SHE GOES
# 46  2UW7JaomAMuX9pZrjVpHAU                                    La Bebe - Remix
# 47  4iZ4pt7kvcaH6Yo8UoZ4s2                                             Snooze
# 48  1s7oOCT8vauUh01PbJD6ps                      Calm Down (with Selena Gomez)
# 49  0V3wPSX9ygBnCm8psDIegu                                          Anti-Hero
#
#     song_duration                                           song_url  \
# 0          230480  https://open.spotify.com/track/56y1jOTK0XSvJzV...
# 1          184400  https://open.spotify.com/track/7x9aauaA9cu6tyf...
# 2          178426  https://open.spotify.com/track/1BxfuPKGuaTgP7a...
# 3          172964  https://open.spotify.com/track/5mjYQaktjmjcMKc...
# 4          172797  https://open.spotify.com/track/5RqSsdzTNPX1uzk...
# 5          131872  https://open.spotify.com/track/3rUGC1vUpkDG9CZ...
# 6          197920  https://open.spotify.com/track/7ABLbnD53cQK00m...
# 7          219724  https://open.spotify.com/track/1kuGVB7EU95pJOb...
# 8          186000  https://open.spotify.com/track/6XbtvPmIpyCbjuT...
# 9          212878  https://open.spotify.com/track/7mXuWTczZNxG5ED...
# 10         222369  https://open.spotify.com/track/6wf7Yu7cxBSPrRl...
# 11         176579  https://open.spotify.com/track/1vYXt7VSjH9JIM5...
# 12         125040  https://open.spotify.com/track/4rXLjWdF2ZZpXCV...
# 13         212953  https://open.spotify.com/track/1odExI7RdWc4BT5...
# 14         183956  https://open.spotify.com/track/5XeFesFbtLpXzIV...
# 15         184783  https://open.spotify.com/track/3IX0yuEVvDbnqUw...
# 16         132359  https://open.spotify.com/track/59NraMJsLaMCVtw...
# 17         167303  https://open.spotify.com/track/4Dvkj6JhhA12EX0...
# 18         153946  https://open.spotify.com/track/1Qrg8KqiBpW07V7...
# 19         227195  https://open.spotify.com/track/4KULAymBBJcPRpk...
# 20         186455  https://open.spotify.com/track/25OeKzcqakFPaJl...
# 21         200373  https://open.spotify.com/track/3xMHXmedL5Rvfxm...
# 22         211141  https://open.spotify.com/track/2gyxAWHebV7xPYV...
# 23         230453  https://open.spotify.com/track/7MXVkk9YMctZqd1...
# 24         191466  https://open.spotify.com/track/6uIIdjYTxxpWOyW...
# 25         229133  https://open.spotify.com/track/2FDTHlrBguDzQkp...
# 26         265360  https://open.spotify.com/track/5PyDJG7SQRgWXef...
# 27         310490  https://open.spotify.com/track/3RaCGXCiiMufRPo...
# 28         195986  https://open.spotify.com/track/6XSqqQIy7Lm7Snw...
# 29         142334  https://open.spotify.com/track/4bw8mcDUSRWfQo6...
# 30         187026  https://open.spotify.com/track/5h1BN75CEh8wdSw...
# 31         231693  https://open.spotify.com/track/6irysuQyZWd7Bjj...
# 32         200600  https://open.spotify.com/track/7DSAEUvxU8FajXt...
# 33         231000  https://open.spotify.com/track/4lIxdJw6W3Fg4vU...
# 34         231826  https://open.spotify.com/track/1p80LdxRV74UKvL...
# 35         165582  https://open.spotify.com/track/63ui2w3QJBp8xx0...
# 36         260253  https://open.spotify.com/track/2LBqCSwhJGcFQeT...
# 37         154374  https://open.spotify.com/track/54zcJnb3tp9c5OV...
# 38         233478  https://open.spotify.com/track/3w3y8KPTfNeOKPi...
# 39         215466  https://open.spotify.com/track/6WzRpISELf3YglG...
# 40         154666  https://open.spotify.com/track/5sdQOyqq2IDhvmx...
# 41         170297  https://open.spotify.com/track/5wjsJIUf6pdrwau...
# 42         244360  https://open.spotify.com/track/3JvKfv6T31zO0in...
# 43         194563  https://open.spotify.com/track/2yzshFeBIwH8tWI...
# 44         211582  https://open.spotify.com/track/6wsqVwoiVH2kde4...
# 45         231704  https://open.spotify.com/track/7ro0hRteUMfnOio...
# 46         234352  https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 47         201800  https://open.spotify.com/track/4iZ4pt7kvcaH6Yo...
# 48         239317  https://open.spotify.com/track/1s7oOCT8vauUh01...
# 49         200690  https://open.spotify.com/track/0V3wPSX9ygBnCm8...
#
#     song_popularity            song_added                album_id  \
# 0                76  2023-09-29T08:46:06Z  1bBez9PNvkJPW08bU7NYta
# 1                97  2023-09-29T08:46:06Z  53985D8g3JcGBoULSOYYKX
# 2                98  2023-09-29T08:46:06Z  1NAmidJlEaVgA3MpcPFYGq
# 3                93  2023-09-29T08:46:06Z  18ogtNq9F7DmMkNYO6Xb4k
# 4                92  2023-09-29T08:46:06Z  0FqAaUEyKCyUNFE1uQPZ7i
# 5                90  2023-09-29T08:46:06Z  3UOV8XvCwMKaATRNXrYCjN
# 6                97  2023-09-29T08:46:06Z  3puAvurwvtvi1rodndIPW8
# 7                94  2023-09-29T08:46:06Z  1xJHno7SmdVtZAtXbdbDZp
# 8                95  2023-09-29T08:46:06Z  07kam1Dks7GIucbSelfvyX
# 9                94  2023-09-29T08:46:06Z  4jox3ip1I39DFC2B7R5qLH
# 10               96  2023-09-29T08:46:06Z  3AafSrFIbJPH6BJHiJm1Cd
# 11               95  2023-09-29T08:46:06Z  5cH7FqB7JD5q1tJXJ7FHYu
# 12               95  2023-09-29T08:46:06Z  5qmZefgh78fN3jsyPPlvuw
# 13               94  2023-09-29T08:46:06Z  6NcI39WPu4kY6Tul11nhSv
# 14               93  2023-09-29T08:46:06Z  78bpIziExqiI9qztvNFlQu
# 15               92  2023-09-29T08:46:06Z  1xJHno7SmdVtZAtXbdbDZp
# 16               92  2023-09-29T08:46:06Z  5MU0RmBSpoSxOPYBfcobDc
# 17               93  2023-09-29T08:46:06Z  5r36AJ6VOJtp00oxSkBZ5h
# 18               91  2023-09-29T08:46:06Z  1nrVofqDRs7cpWXJ49qTnP
# 19               92  2023-09-29T08:46:06Z  6PbnGueEO6LGodPfvNldYf
# 20               85  2023-09-29T08:46:06Z  52PtAAvfi8ZGTRK5c700y4
# 21               79  2023-09-29T08:46:06Z  3WLJmMZUeDOuERFAk1Mxs6
# 22               92  2023-09-29T08:46:06Z  1xJHno7SmdVtZAtXbdbDZp
# 23               92  2023-09-29T08:46:06Z  2ODvWsOgouMbaA5xf0RkJe
# 24               90  2023-09-29T08:46:06Z  4x6cjOcVz44aiLSOHCLKPd
# 25               93  2023-09-29T08:46:06Z  5l0QlaI3wdZpE7ggoO5Rwg
# 26               67  2023-09-29T08:46:06Z  1bBez9PNvkJPW08bU7NYta
# 27               89  2023-09-29T08:46:06Z  4DjJtllSDzVDBf7PYtsHaT
# 28               93  2023-09-29T08:46:06Z  4jtQUtS4ABgER3DnGfKJCv
# 29               80  2023-09-29T08:46:06Z  3Fk8yQvPlCHgwR2pNhEIRA
# 30               93  2023-09-29T08:46:06Z  7ixOAT89NSsgUITYc5ByB5
# 31               92  2023-09-29T08:46:06Z  42D6fdFJ4SLnh4jXZJrsNa
# 32               71  2023-09-29T08:46:06Z  5DvJgsMLbaR1HmAI6VhfcQ
# 33               81  2023-09-29T08:46:06Z  2QJmrSgbdM35R67eoGQo4j
# 34               81  2023-09-29T08:46:06Z  2QJmrSgbdM35R67eoGQo4j
# 35               83  2023-09-29T08:46:06Z  72GhGik5fsSeFkgpjsllVj
# 36               89  2023-09-29T08:46:06Z  4AdZV63ycxFLF6Hcol0QnB
# 37               88  2023-09-29T08:46:06Z  0FqAaUEyKCyUNFE1uQPZ7i
# 38               90  2023-09-29T08:46:06Z  58ufpQsJ1DS5kq4hhzQDiI
# 39               92  2023-09-29T08:46:06Z  5O0zUvdnJr0RbWzLFneN2i
# 40               92  2023-09-29T08:46:06Z  5V729UqvhwNOcMejx0m55I
# 41               83  2023-09-29T08:46:06Z  12v3LOTr03ykEMdyekvM1X
# 42               90  2023-09-29T08:46:06Z  0Gf1yE895FKK4YWVRuAeg8
# 43               83  2023-09-29T08:46:06Z  5i9lMMUZ1QZNsLEE3j50kT
# 44               92  2023-09-29T08:46:06Z  18NOKLkZETa4sWwLMIm0UZ
# 45               93  2023-09-29T08:46:06Z  5gCcb5fsSb6w5K8SyJrgtB
# 46               93  2023-09-29T08:46:06Z  6aBVGuOUEuX18rHxyDWbti
# 47               91  2023-09-29T08:46:06Z  07w0rG5TETcyihsEIZR3qG
# 48               80  2023-09-29T08:46:06Z  0nayxjaX54Frd7GsZq6Pbs
# 49               92  2023-09-29T08:46:06Z  151w1FgRZfnKZA9FEcg9Z3
#
#                  artist_id
# 0   5cj0lLjcoR7YOSnhnX0Po5
# 1   6HaGTQPmzraVmaVxvz6EUc
# 2   06HL4z0CvFAxyc27GXpf02
# 3   7uMDnSZyUYNBPLhPMNuaM2
# 4   790FomKkXshlbRYZFtlgla
# 5   45dkTj5sMRSjrmBSBeiHym
# 6   7iK8PXO48WeuP03g8YR51W
# 7   1McMsnEElThX1knmY4oliG
# 8   52iwsT98xCoGgiGntTiR7K
# 9   12GqGscKJx3aE4t07u7eVZ
# 10  6qqNVTkY8uBg9cP3Jd7DAH
# 11  6M2wZ9GZgrQXHCFfjv46we
# 12  2hlmm7s2ICUX0LVIhVFlZQ
# 13  33NVpKoXjItPwUJTMZIOiY
# 14  7Ln80lUS6He07XvHI8qqHH
# 15  1McMsnEElThX1knmY4oliG
# 16  5wCmhq5J2hPwL2r0eKurxn
# 17  6KImCVD70vtIoJWnq6nGn3
# 18  7tYKF4w9nC0nq9CsPZTHyP
# 19  40ZNYROS4zLfyyBSs2PGe2
# 20  66ihevNkSYNzRAl44dx6jJ
# 21  4zCH9qm4R2DADamUHMCa6O
# 22  1McMsnEElThX1knmY4oliG
# 23  1Xyo4u8uXC1ZmMpatF05PJ
# 24  6dLuQ5qXxIuWc5urxfIiZR
# 25  6Ip8FS7vWT1uKkJSweANQK
# 26  5cj0lLjcoR7YOSnhnX0Po5
# 27  3TVXtAsR1Inumwj472S9r4
# 28  2LRoIwlKmHjgvigdNGBHNo
# 29  1r4hJ1h58CWwUQe3MxPuau
# 30  3JsHnjpbhX4SnySpvpa9DK
# 31  6nVcHLIgY5pE2YCl8ubca1
# 32  5YGY8feqx7naU7z4HrwZM6
# 33  06HL4z0CvFAxyc27GXpf02
# 34  06HL4z0CvFAxyc27GXpf02
# 35  4q3ewBCX7sLwd24euuV69X
# 36  1Xyo4u8uXC1ZmMpatF05PJ
# 37  790FomKkXshlbRYZFtlgla
# 38  0du5cEVh5yTK9QJze8zA0C
# 39  1Xyo4u8uXC1ZmMpatF05PJ
# 40  6HvZYsbFfjnjFrWF950C9d
# 41  0EmeFodog0BfCgMzAIvKQp
# 42  2txHhyCwHjUEpJjWrEyqyX
# 43  6XkjpgcEsYab502Vr1bBeW
# 44  0Y5tJX1MQlPlqiwlOH1tJY
# 45  4q3ewBCX7sLwd24euuV69X
# 46  1NNRWkhwmcXRimFYSBpB1y
# 47  7tYKF4w9nC0nq9CsPZTHyP
# 48  46pWGuE3dSwY3bMMXGBvVS
# 49  06HL4z0CvFAxyc27GXpf02
